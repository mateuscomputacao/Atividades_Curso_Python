# %% [markdown]
# # Aula 04: Estruturas de Decisão - Resolução e Lista de Exercícios
#
# Nesta aula, não vamos aprender comandos novos! Vamos treinar o que aprendemos sobre `if`, `elif`, `else`, e os operadores lógicos `and`, `or`, `not` com bastante prática.

# %% [markdown]
# ## Como resolver um problema de programação?
#
# 1.  **Entenda o problema:** Leia com atenção o que está sendo pedido.
# 2.  **Identifique as Entradas e Saídas:** O que eu recebo do usuário? O que eu devo mostrar na tela?
# 3.  **Esboce o Passo a Passo (Algoritmo):** "Primeiro, peço o valor X. Depois verifico se X é maior que 10. Se sim, faço isso."
# 4.  **Codifique:** Transforme seu passo a passo em código Python.
# 5.  **Teste:** Execute com os valores de exemplo e veja se funciona.

# %% [markdown]
# ## Exemplo Resolvido 1: Ano Bissexto
#
# **O problema:** Crie um programa que peça um ano (ex: 2024) e informe se ele é Bissexto ou não.
#
# *Regra do Ano Bissexto:*
# Ele precisa ser múltiplo de 4 (`ano % 4 == 0`).
# Mas se for fim de século (múltiplo de 100), ele **não** é bissexto, a menos que ele também seja múltiplo de 400.

# %%
# Solução do Professor
ano = int(input("Digite o ano: "))

if (ano % 4 == 0 and ano % 100 != 0) or (ano % 400 == 0):
    print(f"O ano {ano} É bissexto!")
else:
    print(f"O ano {ano} NÃO é bissexto.")
# Out:
# O ano 2026 NÃO é bissexto.

# %% [markdown]
# ## Exemplo Resolvido 2: Calculadora Simples
#
# **O problema:** Peça dois números e um operador matemático (`+`, `-`, `*` ou `/`) ao usuário. Imprima o resultado da operação.

# %%
num1 = float(input("Digite o primeiro número: "))
op = input("Digite a operação (+, -, *, /): ")
num2 = float(input("Digite o segundo número: "))

if op == "+":
    print(f"Resultado: {num1 + num2}")
elif op == "-":
    print(f"Resultado: {num1 - num2}")
elif op == "*":
    print(f"Resultado: {num1 * num2}")
elif op == "/":
    # Cuidados extras em programação: não se divide por zero!
    if num2 == 0:
        print("Erro: Divisão por zero.")
    else:
        print(f"Resultado: {num1 / num2}")
else:
    print("Operador inválido!")
# Out:
# Resultado: 3.0

# %% [markdown]
# ---
#
# ## Lista de Exercícios
#
# Agora é a sua vez. Resolva os exercícios abaixo nas células vazias.
#
# ### Desafio 1: Vogal ou Consoante
# Faça um programa que verifique se uma letra digitada é vogal ou consoante. Lembre-se, vogais são `a`, `e`, `i`, `o`, `u`.

# %%
# Seu código aqui

letra = input("Digite uma letra: ").lower()

if letra == "a" or letra == "e" or letra == "i" or letra == "o" or letra == "u":
  print("\nA letra é uma vogal")
else:
  print("\nA letra é uma consoante")
# Out:
# Digite uma letra: g
#
# A letra é uma consoante

# %% [markdown]
# ### Desafio 2: Aumento de Salário
# Faça um programa que calcule o aumento de salário de um funcionário.
# - Para salários maiores que R$ 1500,00, aumento de 10%.
# - Para salários menores ou iguais a R$ 1500,00, aumento de 15%.
# Multiplicar um valor por 1.10 é dar 10% de aumento.

# %%
# Seu código aqui

salario = float(input("Qual o salário atual? "))

if salario > 1500:
  print(f"\nSeu salário terá 10% de aumento, passando a ser de {round(salario * 1.10, 2)}")
else:
    print(f"\nSeu salário terá 15% de aumento, passando a ser de {round(salario * 1.15, 2)}")
# Out:
# Qual o salário atual? 1220
#
# Seu salário terá 15% de aumento, passando a ser de 1403.0

# %% [markdown]
# ### Desafio 3: Triângulos
# Peça os 3 lados de um triângulo. O programa deverá informar se os valores formam um triângulo. Caso formem, diga o tipo do triângulo:
# - Equilátero: 3 lados iguais;
# - Isósceles: 2 lados iguais;
# - Escaleno: 3 lados diferentes.
# *Dica: Para formar um triângulo, a soma de quaisquer dois lados precisa ser maior que o terceiro lado.*

# %%
# Seu código aqui

lado_a = int(input("Digite o tamanho do primeiro lado: "))
lado_b = int(input("Digite o tamanho do segundo lado: "))
lado_c = int(input("Digite o tamanho do terceiro lado: "))

a = lado_a + lado_b
b = lado_b + lado_c
c = lado_a + lado_c

if a > lado_c and b > lado_a and c > lado_b:
  print("\nAs medidas formam um triângulo!")
  if lado_a == lado_b and lado_b == lado_c and lado_c == lado_a:
    print("O triângulo é equilátero.")

  else:
    if lado_a != lado_b and lado_b != lado_c and lado_c != lado_a:
      print("O triângulo é escaleno.")

    else:
      print("O triângulo é isósceles.")
else:
  print("\nAs medidas não formam um triângulo.")
# Out:
# Digite o tamanho do primeiro lado: 10
# Digite o tamanho do segundo lado: 1
# Digite o tamanho do terceiro lado: 1
#
# As medidas não formam um triângulo.

# %% [markdown]
# ### Desafio 4: Verificação Simples
#
# Crie uma função em Python que receba um número inteiro como entrada e retorne `True` se o número for positivo, e `False` caso contrário. Considere 0 como não positivo.

# %%
numero = int(input("Digite um número inteiro: "))

if numero == 0:
  booleano = False
elif numero % 2 == 0:
  booleano = True
else:
  booleano = False

print(booleano)

# %% [markdown]
# ### Desafio 5: Par e Positivo
#
# Escreva uma função que aceite um número inteiro e retorne `True` se o número for par **E** positivo. Caso contrário, deve retornar `False`.

# %%
numero = int(input("Digite um número inteiro: "))

if numero % 2 == 0 and numero > 0:
  booleano = True
else:
  booleano = False

print(booleano)

# %% [markdown]
# ### Desafio 6: Ano Bissexto
#
# Crie uma função que determine se um ano fornecido é um ano bissexto. Um ano é bissexto se for divisível por 4, mas não por 100, a menos que também seja divisível por 400.

# %%
ano = int(input("Digite um ano: "))

if (ano % 4 == 0 and ano % 100 != 0) or ano % 400 == 0:
  print("\nO ano é bissexto.")
else:
  print("\nO ano não é bissexto.")

# %% [markdown]
# ### Desafio 7: Elegibilidade para Votar e Dirigir
#
# Desenvolva uma função que receba a idade de uma pessoa e determine sua elegibilidade para votar e/ou dirigir. Retorne uma string indicando:
# - 'Apto para votar e dirigir' (idade >= 18)
# - 'Apto apenas para votar' (16 <= idade < 18)
# - 'Não apto' (idade < 16)
#
# Utilize estruturas de decisão com operadores lógicos.

# %%
idade = int(input("Digite sua idade: "))

if idade >= 18:
  print("\nApto para votar e dirigir")
elif 16 <= idade < 18:
  print("\nApto apenas para votar")
else:
  print("\nNão apto")

# %% [markdown]
# ### Desafio 8: Ponto Dentro de Retângulo
#
# Escreva uma função que receba as coordenadas de um ponto `(x, y)` e as coordenadas de dois pontos que definem um retângulo `(x1, y1)` e `(x2, y2)`, onde `(x1, y1)` é o canto inferior esquerdo e `(x2, y2)` é o canto superior direito. A função deve retornar `True` se o ponto `(x, y)` estiver **dentro ou na borda** do retângulo, e `False` caso contrário.

# %%
x_origem_1 = int(input("Digite a cordenada -X1- que define o canto infereior/esquerdo do retângulo: "))
y_origem_1 = int(input("Digite a cordenada -Y1- que define o canto infereior/esquerdo do retângulo: "))
x_origem_2 = int(input("Digite a cordenada -X2- que define o canto superior/direito do retângulo: "))
y_origem_2 = int(input("Digite a cordenada -Y2- que define o canto superior/direito do retângulo: "))
x_ponto = int(input("\nDigite a cordenada -X- do ponto a ser descoberto: "))
y_ponto = int(input("Digite a cordenada -Y- do ponto a ser descoberto: "))

if x_origem_1 <= x_ponto <= x_origem_2 and y_origem_1 <= y_ponto <= y_origem_2:
  print("\nO ponto está dentro ou na borda do retângulo.")
else:
  print("\nO ponto está fora do retângulo.")

# %% [markdown]
# ### Desafio 9: Tipo de Triângulo com Validação
#
# Desenvolva uma função que receba três números representando os comprimentos dos lados de um triângulo. A função deve primeiro verificar se os lados podem formar um triângulo (a soma de quaisquer dois lados deve ser maior que o terceiro lado). Se for um triângulo válido, ela deve retornar:
# - 'Equilátero' (todos os lados iguais)
# - 'Isósceles' (dois lados iguais)
# - 'Escaleno' (todos os lados diferentes)
# - 'Não é um triângulo válido' (se não atender à condição de formação do triângulo).
#
# Combine as condições usando operadores lógicos.

# %%
lado_a = int(input("Digite o tamanho do primeiro lado: "))
lado_b = int(input("Digite o tamanho do segundo lado: "))
lado_c = int(input("Digite o tamanho do terceiro lado: "))

a = lado_a + lado_b
b = lado_b + lado_c
c = lado_a + lado_c

if a > lado_c and b > lado_a and c > lado_b:
  print("As medidas formam um triângulo!")
  if lado_a == lado_b and lado_b == lado_c and lado_c == lado_a:
    print("O triângulo é equilátero.")

  else:
    if lado_a != lado_b and lado_b != lado_c and lado_c != lado_a:
      print("O triângulo é escaleno.]")

    else:
      print("O triângulo é isósceles.")
else:
  print("As medidas não formam um triângulo")

# %% [markdown]
# ### Desafio 10: Elegibilidade para Desconto de Idosos
#
# Crie uma função que receba a idade de uma pessoa (inteiro) e um valor booleano indicando se ela é membro de um programa de fidelidade (`is_member`). A função deve retornar `True` se a pessoa for elegível para um desconto, e `False` caso contrário. Uma pessoa é elegível se:
# - Tiver 65 anos ou mais **E** for membro do programa.
# - OU tiver 70 anos ou mais (independentemente de ser membro).
#
# Combine as condições usando operadores lógicos.

# %%
def verificar_desconto_idoso(idade, membro):
    condicao1 = (idade >= 65 and membro)
    condicao2 = (idade >= 70)
    return condicao1 or condicao2


idade = int(input("Digite a idade: "))
membro = input("É membro? (s/n): ").lower() == 's'
print(f"Elegível para desconto (idade={idade}, membro={membro}): {verificar_desconto_idoso(idade, membro)}")

# %% [markdown]
# ### Desafio 11: Cálculo de Nota com Condições Múltiplas
#
# Implemente uma função que receba uma pontuação (um número inteiro entre 0 e 100) e retorne a letra correspondente à nota, seguindo estas regras, e também valide a pontuação:
# - A: 90-100
# - B: 80-89
# - C: 70-79
# - D: 60-69
# - E: Abaixo de 60
# - 'Pontuação Inválida': Se a pontuação estiver fora do intervalo de 0 a 100.
#
# Combine as verificações de intervalo com operadores lógicos.

# %%
pontuacao = int(input("Digite sua pontuação (de 0 a 100): "))

if pontuacao < 0 or pontuacao > 100:
  print("Pontuação inválida.")
elif 90 <= pontuacao <= 100:
  print("Pontuação na classe -A-")
elif 80 <= pontuacao <= 89:
  print("Pontuação na classe -B-")
elif 70 <= pontuacao <= 79:
  print("Pontuação na classe -C-")
elif 60 <= pontuacao <= 69:
  print("Pontuação na classe -D-")
elif pontuacao < 60:
  print("Pontuação na classe -E-")

# %% [markdown]
# ### Desafio 12: Elegibilidade para Desconto Aninhada
#
# Você precisa determinar se um cliente é elegível para um desconto especial. Crie uma função que receba os seguintes parâmetros:
# - `tipo_membro` (string: 'premium', 'novo', 'regular')
# - `gastos_mes_atual` (float)
# - `primeira_compra` (boolean)
# - `item_em_promocao` (boolean)
#
# O cliente é elegível para o desconto se atender a **uma** das seguintes condições **E** o item não estiver em promoção:
# 1. É um membro 'premium' **E** seus gastos no mês atual são superiores a R$ 500.
# 2. É um membro 'novo' **E** esta é a sua primeira compra.
#
# A função deve retornar `True` se o cliente for elegível para o desconto, e `False` caso contrário. Use uma combinação complexa de operadores lógicos e estruturas de decisão alinhadas.

# %%
tipo_membro = input("Qual é o seu tipo de membro? (Premium, Novo ou Regular): ").lower()
gastos_mes = float(input("Em quanto estão os seus gastos do mês atual, em reais?: "))
primeira_compra = int(input("Está é sua primeira compra? (Se SIM, responda: 1. Se NÂO, reponda: 0): "))
item_promocao = int(input("O item desejado está em promoção? (Se SIM, responda: 1. Se NÂO, reponda: 0): "))

if ((tipo_membro == "premium" and gastos_mes > 500) or (tipo_membro == "novo" and primeira_compra)) and not item_promocao:
  print("\nTrue")
else:
  print("\nFalse")
# Out:
# Qual é o seu tipo de membro? (Premium, Novo ou Regular): novo
# Em quanto estão os seus gastos do mês atual, em reais?: 2500
# Está é sua primeira compra? (Se SIM, responda: 1. Se NÂO, reponda: 0): 0
# O item desejado está em promoção? (Se SIM, responda: 1. Se NÂO, reponda: 0): 1
#
# False

# %% [markdown]
# ### Desafio 13: Aprovação de Aluno Complexa
#
# Crie uma função em Python que receba os seguintes parâmetros:
# - `nota_final` (int): A nota final do aluno (de 0 a 100).
# - `frequencia_percentual` (int): A porcentagem de frequência do aluno (de 0 a 100).
# - `completou_projetos` (boolean): `True` se o aluno completou todos os projetos, `False` caso contrário.
#
# A função deve retornar `True` se o aluno for aprovado, e `False` caso contrário, seguindo as seguintes regras:
# 1. O aluno é aprovado se `nota_final` for maior ou igual a 70 **E** `frequencia_percentual` for maior ou igual a 75 **E** `completou_projetos` for `True`.
# 2. **Exceção:** Se o aluno tiver `nota_final` maior ou igual a 90, ele será aprovado **mesmo que** a `frequencia_percentual` seja menor que 75, desde que `completou_projetos` seja `True`.
# 3. Em todos os outros casos, o aluno é reprovado.

# %%
def verificar_aprovacao():

    nota_final = int(input("Digite a nota final (0-100): "))
    frequencia_percentual = int(input("Digite a frequência (0%-100%): "))


    resposta_projeto = input("Completou todos os projetos? (s/n): ").lower()
    completou_projetos = resposta_projeto == 's'


    condicao_padrao = (nota_final >= 70 and frequencia_percentual >= 75)


    condicao_excecao = (nota_final >= 90)


    if (condicao_padrao or condicao_excecao) and completou_projetos:
        return True
    else:
        return False

resultado = verificar_aprovacao()
print(f"Aluno aprovado? {resultado}")
# Out:
# Digite a nota final (0-100): 50
# Digite a frequência (0-100): 80
